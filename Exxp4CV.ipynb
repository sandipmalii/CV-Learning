# %% [markdown]
# <a href="https://colab.research.google.com/github/sandipmalii/CV-Learning/blob/main/Exxp4CV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required libraries
# !pip install scipy scikit-image gdown

# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from skimage import io, filters, color
from skimage.util import random_noise
from skimage.feature import canny
import gdown

# Download the image from Google Drive
file_id = '10uJrjMsw4c5sEsdPnlfdxGlN3CqpzFtk'
url = f'https://drive.google.com/uc?id={file_id}'
output = 'image.jpg'
gdown.download(url, output, quiet=False)

# Load the image
image = io.imread('image.jpg', as_gray=True)

# Apply thresholding to convert the image to binary
threshold = filters.threshold_otsu(image)
binary_image = image > threshold

# Display the binary image
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.title('Binary Image')
plt.imshow(binary_image, cmap='gray')
plt.axis('off')

# Apply Canny edge detector
edges = canny(binary_image, sigma=1.0)

# Display the edges
plt.subplot(1, 2, 2)
plt.title('Canny Edge Detection')
plt.imshow(edges, cmap='gray')
plt.axis('off')
plt.show()
# Out:
# ...
# Downloading...
# From: https://drive.google.com/uc?id=10uJrjMsw4c5sEsdPnlfdxGlN3CqpzFtk
# To: /content/image.jpg
# 100%|██████████| 38.1k/38.1k [00:00<00:00, 19.9MB/s]
